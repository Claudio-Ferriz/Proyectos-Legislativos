# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel('https://github.com/Claudio-Ferriz/Proyectos-Legislativos/raw/refs/heads/main/Proyectos%20Legislativos.xlsx')
df
# Out:
#             id proyecto_id                                             titulo  \
# 0            0  HCDN276217  PEDIDO DE INFORMES AL PODER EJECUTIVO SOBRE DI...
# 1            1  HCDN276218  EXPRESAR ADHESIÓN Al “Día Internacional de las...
# 2            2  HCDN276210  inStitúyase el 24 de junio de cada año como “D...
# 3            3  HCDN276226  SOLICITAR AL PODER EJECUTIVO DISPONGA LA REGLA...
# 4            4  HCDN276224  PEDIDO DE INFORMES VERBALES A La titular de la...
# ...        ...         ...                                                ...
# 102875  102875  HCDN092251  ACCESIBILIDAD Y TRANSPORTE PARA PERSONAS CON D...
# 102876  102876  HCDN092299  REGLAMENTO DE LA H CAMARA DE DIPUTADOS DE LA N...
# 102877  102877  HCDN092334  DECLARAR DE INTERES DE LA H CAMARA EL "29 CONG...
# 102878  102878  HCDN092250  CREACION Y FUNCIONAMIENTO DE LAS COMISIONES IN...
# 102879  102879  HCDN092249  CODIGO CIVIL: MODIFICACION DEL INCISO E) DEL A...
#
#        publicacion_fecha publicacion_id camara_origen exp_diputados  \
# 0             2024-06-24   HCDN142TP080     Diputados   3297-D-2024
# 1             2024-06-24   HCDN142TP080     Diputados   3294-D-2024
# 2             2024-06-24   HCDN142TP080     Diputados   3293-D-2024
# 3             2024-06-24   HCDN142TP080     Diputados   3292-D-2024
# 4             2024-06-24   HCDN142TP080     Diputados   3289-D-2024
# ...                  ...            ...           ...           ...
# 102875        2008-03-03   HCDN126TP001     Diputados   0005-D-2008
# 102876        2008-03-03   HCDN126TP001     Diputados   0004-D-2008
# 102877        2008-03-03   HCDN126TP001     Diputados   0003-D-2008
# 102878        2008-03-03   HCDN126TP001     Diputados   0002-D-2008
# 102879        2008-03-03   HCDN126TP001     Diputados   0001-D-2008
#
#        exp_senado         tipo
# 0             NaN   RESOLUCION
# 1             NaN   RESOLUCION
# 2             NaN          LEY
# 3             NaN   RESOLUCION
# 4             NaN   RESOLUCION
# ...           ...          ...
# 102875        NaN          LEY
# 102876        NaN   RESOLUCION
# 102877        NaN  DECLARACION
# 102878        NaN          LEY
# 102879        NaN          LEY
#
# [102880 rows x 9 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102880 entries, 0 to 102879
# Data columns (total 9 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   id                 102880 non-null  int64
#  1   proyecto_id        102880 non-null  object
#  2   titulo             102880 non-null  object
#  3   publicacion_fecha  102880 non-null  datetime64[ns]
#  4   publicacion_id     100201 non-null  object
#  5   camara_origen      102880 non-null  object
#  6   exp_diputados      102880 non-null  object
#  7   exp_senado         3235 non-null    object
#  8   tipo               102880 non-null  object
# dtypes: datetime64[ns](1), int64(1), object(7)
# memory usage: 7.1+ MB

# %%
df.shape
# Out:
# (102880, 9)

# %%
plt.figure(figsize=[12,5])
sns.countplot(df, x='camara_origen', hue='tipo')
# Out:
# <Axes: xlabel='camara_origen', ylabel='count'>
